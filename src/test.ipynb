# %%
import json

# %%
with open("../results/with_audit/with_audit_2404.04958.json", "r") as file:
    data = json.load(file)

# %%
data["1"]["audit-trail"]["extract_equation"]["EQN1"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data["1"]["audit-trail"]["extract_equation"]["EQN1"]
#
# TypeError: list indices must be integers or slices, not str

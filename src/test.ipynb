# %%
import json

# %%
with open("../results/with_audit/dataset.json", "r") as file:
    data = json.load(file)

# %%
for k,v in data.items():
    values = len(data[k].keys())
    print((values))
# Out:
# 7
# 7
# 7
# 0
# 7

# %%
keys = data.keys()
keys
# Out:
# dict_keys(['arXiv:2405.07909', 'arXiv:2510.12545', 'arXiv:2410.08937', 'arXiv:2503.18843', 'arXiv:2410.07045'])

# %%
data["arXiv:2503.18843"]
# Out:
# {}
